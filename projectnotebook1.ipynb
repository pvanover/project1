# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Paige Vanover__
#
# student

# %% [markdown]
# *I am interested in data science because it is a versatile field with applications in every industry.*

# %% [markdown]
# ### My code is supposed to add 2 and 2 together

# %%
print(2+2)
# Out:
# 4

# %% [markdown]
# - here is a bulleted list
# - here is another bullet point
# >here is a quote that sticks out
# 1. this is a numbered item list
# 2. item 2
